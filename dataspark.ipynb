# %% [markdown]
# # **1.Set of Data Reading**

# %%
import pandas as pd

# %% [markdown]
# ## **1.1 Customers_Data**

# %%
Customers_df = pd.read_csv("DataSet/Customers.csv", encoding='latin1')
Customers_df
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
# ...

# %%
Customers_df.shape
# Out:
# (15266, 10)

# %%
Customers_missing_value_rows = Customers_df[Customers_df.isna().any(axis=1)]
Customers_missing_value_rows
# Out:
#       CustomerKey  Gender                Name               City State Code  \
# 5304       729681  Female    Rossana Padovesi            Polvica        NaN
# 5316       732289    Male        Indro Piccio          Varcaturo        NaN
# 5372       742042    Male     Amaranto Loggia          Casaferro        NaN
# 5377       742886  Female       Edmonda Capon           Terzigno        NaN
# 5378       743343  Female        Ambra Sagese  Pomigliano D'Arco        NaN
# 5485       759705    Male    Callisto Lo Duca            Casilli        NaN
# 5525       765589    Male  Michelino Lucchesi       Pompei Scavi        NaN
# 5531       766410    Male   Adelmio Beneventi             Licola        NaN
# 5631       781667  Female          Ilda Manna             Napoli        NaN
# 5695       789177    Male   Calogero Folliero      Mariglianella        NaN
#
#        State Zip Code Country Continent    Birthday
# 5304  Napoli    80035   Italy    Europe   4/18/1981
# ...

# %%
# Replace NaN in 'State Code' where 'State' is 'Napoli' with the desired state code (e.g., 'NAP')
Customers_df.loc[Customers_df['State'] == 'Napoli', 'State Code'] = Customers_df.loc[Customers_df['State'] == 'Napoli', 'State Code'].fillna('NAP')

# %%
# Filter rows where 'State' column is 'Victoria'
Napoli = Customers_df[Customers_df['State'] == 'Napoli']
Napoli
# Out:
#       CustomerKey  Gender                Name               City State Code  \
# 5304       729681  Female    Rossana Padovesi            Polvica        NAP
# 5316       732289    Male        Indro Piccio          Varcaturo        NAP
# 5372       742042    Male     Amaranto Loggia          Casaferro        NAP
# 5377       742886  Female       Edmonda Capon           Terzigno        NAP
# 5378       743343  Female        Ambra Sagese  Pomigliano D'Arco        NAP
# 5485       759705    Male    Callisto Lo Duca            Casilli        NAP
# 5525       765589    Male  Michelino Lucchesi       Pompei Scavi        NAP
# 5531       766410    Male   Adelmio Beneventi             Licola        NAP
# 5631       781667  Female          Ilda Manna             Napoli        NAP
# 5695       789177    Male   Calogero Folliero      Mariglianella        NAP
#
#        State Zip Code Country Continent    Birthday
# 5304  Napoli    80035   Italy    Europe   4/18/1981
# ...

# %%
Customers_missing_value_rows = Customers_df[Customers_df.isna().any(axis=1)]
Customers_missing_value_rows
# Out:
# Empty DataFrame
# Columns: [CustomerKey, Gender, Name, City, State Code, State, Zip Code, Country, Continent, Birthday]
# Index: []

# %%
Customers_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
Customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15266 entries, 0 to 15265
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CustomerKey  15266 non-null  int64
#  1   Gender       15266 non-null  object
#  2   Name         15266 non-null  object
#  3   City         15266 non-null  object
#  4   State Code   15266 non-null  object
#  5   State        15266 non-null  object
#  6   Zip Code     15266 non-null  object
#  7   Country      15266 non-null  object
#  8   Continent    15266 non-null  object
#  9   Birthday     15266 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 1.2+ MB

# %%
# Changing data type.
Customers_df['Birthday'] = pd.to_datetime(Customers_df['Birthday'])
Customers_df['Zip Code'] = pd.to_numeric(Customers_df['Zip Code'], errors='coerce')
Customers_df['Zip Code'] = Customers_df['Zip Code'].fillna(0).astype(int)
Customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15266 entries, 0 to 15265
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CustomerKey  15266 non-null  int64
#  1   Gender       15266 non-null  object
#  2   Name         15266 non-null  object
#  3   City         15266 non-null  object
#  4   State Code   15266 non-null  object
#  5   State        15266 non-null  object
#  6   Zip Code     15266 non-null  int64
#  7   Country      15266 non-null  object
#  8   Continent    15266 non-null  object
#  9   Birthday     15266 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(7)
# memory usage: 1.2+ MB

# %%
Customers_rename = Customers_df.rename(columns={"State Code": "state_code", "Zip Code": "zip_code"})
Customers_rename
# Out:
#        CustomerKey  Gender               Name                 City state_code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
# ...

# %%
Cleaned_Customers_df = pd.DataFrame(Customers_rename)
Cleaned_Customers_df
# Out:
#        CustomerKey  Gender               Name                 City state_code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
# ...

# %%
Cleaned_Customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15266 entries, 0 to 15265
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CustomerKey  15266 non-null  int64
#  1   Gender       15266 non-null  object
#  2   Name         15266 non-null  object
#  3   City         15266 non-null  object
#  4   state_code   15266 non-null  object
#  5   State        15266 non-null  object
#  6   zip_code     15266 non-null  int64
#  7   Country      15266 non-null  object
#  8   Continent    15266 non-null  object
#  9   Birthday     15266 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(7)
# memory usage: 1.2+ MB

# %%
Cleaned_Customers_df.to_csv('customers_updated.csv')

# %% [markdown]
# ## **1.2 Exchange_Data**

# %%
Exchange_Rates_df = pd.read_csv("DataSet/Exchange_Rates.csv", encoding='latin1')
Exchange_Rates_df
# Out:
#             Date Currency  Exchange
# 0       1/1/2015      USD    1.0000
# 1       1/1/2015      CAD    1.1583
# 2       1/1/2015      AUD    1.2214
# 3       1/1/2015      EUR    0.8237
# 4       1/1/2015      GBP    0.6415
# ...          ...      ...       ...
# 11210  2/20/2021      USD    1.0000
# 11211  2/20/2021      CAD    1.2610
# 11212  2/20/2021      AUD    1.2723
# 11213  2/20/2021      EUR    0.8238
# 11214  2/20/2021      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
Exchange_Rates_df.shape
# Out:
# (11215, 3)

# %%
Exchange_Rates_missing_value_rows = Exchange_Rates_df[Exchange_Rates_df.isna().any(axis=1)]
Exchange_Rates_missing_value_rows
# Out:
# Empty DataFrame
# Columns: [Date, Currency, Exchange]
# Index: []

# %%
Exchange_Rates_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
Exchange_Rates_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11215 entries, 0 to 11214
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      11215 non-null  object
#  1   Currency  11215 non-null  object
#  2   Exchange  11215 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 263.0+ KB

# %%
Exchange_Rates_df['Date'] = pd.to_datetime(Exchange_Rates_df['Date'])

# %%
Exchange_Rates_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11215 entries, 0 to 11214
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      11215 non-null  datetime64[ns]
#  1   Currency  11215 non-null  object
#  2   Exchange  11215 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 263.0+ KB

# %%
Exchange_Rates_df.to_csv('Exchange_Rates_updated.csv')

# %% [markdown]
# ## **1.3 Products_Data**

# %%
Products_df = pd.read_csv("DataSet/Products.csv", encoding='latin1')
Products_df
# Out:
#       ProductKey                                   Product Name    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color Unit Cost USD Unit Price USD  SubcategoryKey  \
# ...

# %%
Products_df.shape
# Out:
# (2517, 10)

# %%
Products_missing_value_rows = Products_df[Products_df.isna().any(axis=1)]
Products_missing_value_rows
# Out:
# Empty DataFrame
# Columns: [ProductKey, Product Name, Brand, Color, Unit Cost USD, Unit Price USD, SubcategoryKey, Subcategory, CategoryKey, Category]
# Index: []

# %%
Products_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
Products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ProductKey      2517 non-null   int64
#  1   Product Name    2517 non-null   object
#  2   Brand           2517 non-null   object
#  3   Color           2517 non-null   object
#  4   Unit Cost USD   2517 non-null   object
#  5   Unit Price USD  2517 non-null   object
#  6   SubcategoryKey  2517 non-null   int64
#  7   Subcategory     2517 non-null   object
#  8   CategoryKey     2517 non-null   int64
#  9   Category        2517 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 196.8+ KB

# %%
Products_df['Unit Cost USD'] = Products_df['Unit Cost USD'].str.replace('$', '')
Products_df['Unit Price USD'] = Products_df['Unit Price USD'].str.replace('$', '')

# %%
Products_rename = Products_df.rename(columns={"Unit Cost USD": "unit_cost_USD", "Unit Price USD": "unit_price_USD", "Product Name": "product_name"})
Products_rename
# Out:
#       ProductKey                                   product_name    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color unit_cost_USD unit_price_USD  SubcategoryKey  \
# ...

# %%
Products_rename.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ProductKey      2517 non-null   int64
#  1   product_name    2517 non-null   object
#  2   Brand           2517 non-null   object
#  3   Color           2517 non-null   object
#  4   unit_cost_USD   2517 non-null   object
#  5   unit_price_USD  2517 non-null   object
#  6   SubcategoryKey  2517 non-null   int64
#  7   Subcategory     2517 non-null   object
#  8   CategoryKey     2517 non-null   int64
#  9   Category        2517 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 196.8+ KB

# %%
Products_rename['unit_cost_USD'] = Products_rename['unit_cost_USD'].str.replace(',', '').str.strip().astype(float)
Products_rename['unit_price_USD'] = Products_rename['unit_price_USD'].str.replace(',', '').str.strip().astype(float)

# %%
Products_rename.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ProductKey      2517 non-null   int64
#  1   product_name    2517 non-null   object
#  2   Brand           2517 non-null   object
#  3   Color           2517 non-null   object
#  4   unit_cost_USD   2517 non-null   float64
#  5   unit_price_USD  2517 non-null   float64
#  6   SubcategoryKey  2517 non-null   int64
#  7   Subcategory     2517 non-null   object
#  8   CategoryKey     2517 non-null   int64
#  9   Category        2517 non-null   object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 196.8+ KB

# %%
Cleaned_Products_df = pd.DataFrame(Products_rename)
Cleaned_Products_df
# Out:
#       ProductKey                                   product_name    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color  unit_cost_USD  unit_price_USD  SubcategoryKey  \
# ...

# %%
Cleaned_Products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ProductKey      2517 non-null   int64
#  1   product_name    2517 non-null   object
#  2   Brand           2517 non-null   object
#  3   Color           2517 non-null   object
#  4   unit_cost_USD   2517 non-null   float64
#  5   unit_price_USD  2517 non-null   float64
#  6   SubcategoryKey  2517 non-null   int64
#  7   Subcategory     2517 non-null   object
#  8   CategoryKey     2517 non-null   int64
#  9   Category        2517 non-null   object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 196.8+ KB

# %%
Cleaned_Products_df.to_csv('Products_updated.csv')

# %% [markdown]
# ## **1.4 Sales_Data**

# %%
Sales_df = pd.read_csv("DataSet/Sales.csv", encoding='latin1')
Sales_df
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 0            366000          1   1/1/2016           NaN       265598
# 1            366001          1   1/1/2016     1/13/2016      1269051
# 2            366001          2   1/1/2016     1/13/2016      1269051
# 3            366002          1   1/1/2016     1/12/2016       266019
# 4            366002          2   1/1/2016     1/12/2016       266019
# ...             ...        ...        ...           ...          ...
# 62879       2243030          1  2/20/2021           NaN      1216913
# 62880       2243031          1  2/20/2021     2/24/2021       511229
# 62881       2243032          1  2/20/2021     2/23/2021       331277
# 62882       2243032          2  2/20/2021     2/23/2021       331277
# 62883       2243032          3  2/20/2021     2/23/2021       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# ...

# %%
Sales_df.shape
# Out:
# (62884, 9)

# %%
Sales_df.isna().sum()
# Out:
# Order Number         0
# Line Item            0
# Order Date           0
# Delivery Date    49719
# CustomerKey          0
# StoreKey             0
# ProductKey           0
# Quantity             0
# Currency Code        0
# dtype: int64

# %%
Sales_missing_value_rows = Sales_df[Sales_df.isna().any(axis=1)]
Sales_missing_value_rows
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 0            366000          1   1/1/2016           NaN       265598
# 6            366004          1   1/1/2016           NaN      1107461
# 7            366004          2   1/1/2016           NaN      1107461
# 8            366005          1   1/1/2016           NaN       844003
# 9            366007          1   1/1/2016           NaN      2035771
# ...             ...        ...        ...           ...          ...
# 62867       2243025          1  2/20/2021           NaN      1909290
# 62868       2243025          2  2/20/2021           NaN      1909290
# 62869       2243026          1  2/20/2021           NaN      1737466
# 62872       2243028          1  2/20/2021           NaN      1728060
# 62879       2243030          1  2/20/2021           NaN      1216913
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# ...

# %%
# Calculate the percentage of non-missing (present) data in the 'Delivery Date' column
present_data_percentage = Sales_df['Delivery Date'].notna().mean() * 100

# Display the percentage
print(f"Percentage of data present in the 'Delivery' column: {present_data_percentage:.2f}%")
# Out:
# Percentage of data present in the 'Delivery' column: 20.94%

# %%
# 'Delivery Date' column as 20.94% of data so i am droping this column
Sales_df.drop('Delivery Date', axis=1, inplace=True)

# %%
Sales_df
# Out:
#        Order Number  Line Item Order Date  CustomerKey  StoreKey  ProductKey  \
# 0            366000          1   1/1/2016       265598        10        1304
# 1            366001          1   1/1/2016      1269051         0        1048
# 2            366001          2   1/1/2016      1269051         0        2007
# 3            366002          1   1/1/2016       266019         0        1106
# 4            366002          2   1/1/2016       266019         0         373
# ...             ...        ...        ...          ...       ...         ...
# 62879       2243030          1  2/20/2021      1216913        43         632
# 62880       2243031          1  2/20/2021       511229         0          98
# 62881       2243032          1  2/20/2021       331277         0        1613
# 62882       2243032          2  2/20/2021       331277         0        1717
# 62883       2243032          3  2/20/2021       331277         0         464
#
#        Quantity Currency Code
# ...

# %%
Sales_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
Sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62884 entries, 0 to 62883
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order Number   62884 non-null  int64
#  1   Line Item      62884 non-null  int64
#  2   Order Date     62884 non-null  object
#  3   CustomerKey    62884 non-null  int64
#  4   StoreKey       62884 non-null  int64
#  5   ProductKey     62884 non-null  int64
#  6   Quantity       62884 non-null  int64
#  7   Currency Code  62884 non-null  object
# dtypes: int64(6), object(2)
# memory usage: 3.8+ MB

# %%
Sales_rename_df = Sales_df.rename(columns={"Order Number": "order_number", "Line Item": "line_item", "Order Date": "order_date","Currency Code":"currency_code"})
Sales_rename_df
# Out:
#        order_number  line_item order_date  CustomerKey  StoreKey  ProductKey  \
# 0            366000          1   1/1/2016       265598        10        1304
# 1            366001          1   1/1/2016      1269051         0        1048
# 2            366001          2   1/1/2016      1269051         0        2007
# 3            366002          1   1/1/2016       266019         0        1106
# 4            366002          2   1/1/2016       266019         0         373
# ...             ...        ...        ...          ...       ...         ...
# 62879       2243030          1  2/20/2021      1216913        43         632
# 62880       2243031          1  2/20/2021       511229         0          98
# 62881       2243032          1  2/20/2021       331277         0        1613
# 62882       2243032          2  2/20/2021       331277         0        1717
# 62883       2243032          3  2/20/2021       331277         0         464
#
#        Quantity currency_code
# ...

# %%
Sales_rename_df['order_date'] = pd.to_datetime(Sales_rename_df['order_date'])
Sales_rename_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62884 entries, 0 to 62883
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_number   62884 non-null  int64
#  1   line_item      62884 non-null  int64
#  2   order_date     62884 non-null  datetime64[ns]
#  3   CustomerKey    62884 non-null  int64
#  4   StoreKey       62884 non-null  int64
#  5   ProductKey     62884 non-null  int64
#  6   Quantity       62884 non-null  int64
#  7   currency_code  62884 non-null  object
# dtypes: datetime64[ns](1), int64(6), object(1)
# memory usage: 3.8+ MB

# %%
Cleaned_Sales_df = pd.DataFrame(Sales_rename_df)
Cleaned_Sales_df
# Out:
#        order_number  line_item order_date  CustomerKey  StoreKey  ProductKey  \
# 0            366000          1 2016-01-01       265598        10        1304
# 1            366001          1 2016-01-01      1269051         0        1048
# 2            366001          2 2016-01-01      1269051         0        2007
# 3            366002          1 2016-01-01       266019         0        1106
# 4            366002          2 2016-01-01       266019         0         373
# ...             ...        ...        ...          ...       ...         ...
# 62879       2243030          1 2021-02-20      1216913        43         632
# 62880       2243031          1 2021-02-20       511229         0          98
# 62881       2243032          1 2021-02-20       331277         0        1613
# 62882       2243032          2 2021-02-20       331277         0        1717
# 62883       2243032          3 2021-02-20       331277         0         464
#
#        Quantity currency_code
# ...

# %%
Cleaned_Sales_df.to_csv('Sales_updated.csv')

# %% [markdown]
# ## **1.5 Stores_Data**

# %%
Stores_df = pd.read_csv("DataSet/Stores.csv", encoding='latin1')
Stores_df
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            NaN
#
#     Open Date
# 0    1/1/2008
# 1   1/12/2008
# 2    1/7/2012
# 3    1/1/2010
# ...

# %%
Stores_df.shape
# Out:
# (67, 5)

# %%
Stores_missing_value_rows = Stores_df[Stores_df.isna().any(axis=1)]
Stores_missing_value_rows
# Out:
#     StoreKey Country   State  Square Meters Open Date
# 66         0  Online  Online            NaN  1/1/2010

# %%
# Drop rows with any missing values because online is nat a state so i am drop.
# This will remove any row that contains at least one null value

# Stores_df.dropna(inplace=True)
# I first dropped this online row, but after noticing in the online sales data that people purchased more items online.

# I deleted Online data so reset_index inclination.
# Stores_df.reset_index(drop=True, inplace=True)

Stores_df['Square Meters']=Stores_df['Square Meters'].fillna(value=0)

# %%
Stores_rename_df = Stores_df.rename(columns={"Square Meters": "square_meters", "Open Date": "open_date"})
Stores_rename_df
# Out:
#     StoreKey        Country                         State  square_meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            0.0
#
#     open_date
# 0    1/1/2008
# 1   1/12/2008
# 2    1/7/2012
# 3    1/1/2010
# ...

# %%
Cleaned_Stores_df = pd.DataFrame(Stores_rename_df)
Cleaned_Stores_df
# Out:
#     StoreKey        Country                         State  square_meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            0.0
#
#     open_date
# 0    1/1/2008
# 1   1/12/2008
# 2    1/7/2012
# 3    1/1/2010
# ...

# %%
Cleaned_Stores_df.to_csv('Stores_updated.csv')

# %% [markdown]
# # **2.Connecting to SQL**

# %%
# Load cleaned datasets
customers = pd.read_csv("customers_updated.csv")
sales = pd.read_csv("Sales_updated.csv")
stores = pd.read_csv("Stores_updated.csv")
products = pd.read_csv("Products_updated.csv")
exchange_rates = pd.read_csv("Exchange_Rates_updated.csv")

# %%
import pymysql
# SQL to Python connection.

# %%
#connecting with SQL database with a password.
myconnection = pymysql.connect(host='127.0.0.1' ,user='root',passwd='*********')
# We are not adding a database because we allow a particular one to work inside the database. 
# So, I am now creating a database to work in all types of libraries.

# %%
myconnection.cursor().execute("create database dataspark")
# Out:
# 1

# %%
myconnection.cursor().execute("USE dataspark")
# Out:
# 0

# %%
import numpy as np

def create_table_from_dataframe(df, table_name, connection):
    # Mapping data types
    dtype_mapping = {
        'int64': 'INT',
        'float64': 'FLOAT',
        'object': 'TEXT',
        'datetime64[ns]': 'DATETIME'
    }
    
    # Generate column definitions for the SQL CREATE TABLE statement
    columns = ', '.join(
        f"{col} {dtype_mapping.get(str(dtype), 'TEXT')}" 
        for col, dtype in zip(df.columns, df.dtypes)
    )
    
    # SQL query to create the table
    create_table_sql = f"CREATE TABLE IF NOT EXISTS {table_name} ({columns});"
    
    # Execute the SQL query
    with connection.cursor() as cursor:
        cursor.execute(create_table_sql)
        connection.commit()

def insert_dataframe_to_sql(df, table_name, connection):
    # Ensure all data types are converted to native Python types
    df = df.astype({
        col: 'int' if dtype == np.int64 else 'float' if dtype == np.float64 else 'str' 
        for col, dtype in zip(df.columns, df.dtypes)
    })
    
    # Create a SQL query to insert values into the table
    sql = f"INSERT INTO {table_name} VALUES ({', '.join(['%s'] * len(df.columns))})"
    
    # Convert DataFrame rows to tuples of native Python types
    data = [tuple(row) for row in df.itertuples(index=False, name=None)]
    
    # Insert the data into the table
    with connection.cursor() as cursor:
        cursor.executemany(sql, data)
        connection.commit()

# Create tables and insert data
create_table_from_dataframe(Cleaned_Customers_df, "customers", myconnection)
insert_dataframe_to_sql(Cleaned_Customers_df, "customers", myconnection)

create_table_from_dataframe(Exchange_Rates_df, "exchange_rates", myconnection)
insert_dataframe_to_sql(Exchange_Rates_df, "exchange_rates", myconnection)

create_table_from_dataframe(Cleaned_Products_df, "Products", myconnection)
insert_dataframe_to_sql(Cleaned_Products_df, "Products", myconnection)

create_table_from_dataframe(Cleaned_Sales_df, "sales", myconnection)
insert_dataframe_to_sql(Cleaned_Sales_df, "sales", myconnection)

create_table_from_dataframe(Cleaned_Stores_df, "stores", myconnection)
insert_dataframe_to_sql(Cleaned_Stores_df, "stores", myconnection)
